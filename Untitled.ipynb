# %%
import sys
sys.path.append("D:\Lib_Python")

# %%
import pandas as pd

# %%
test_data = pd.read_csv("./adresses.csv", delimiter=";")

# %%
test_data
# Out:
#                        id  id_fantoir  numero  rep              nom_voie  \
# 0      05001_fuxrfi_00001         NaN       1  NaN  Montée du Serre Lara
# 1      05001_fuxrfi_00002         NaN       2  NaN  Montée du Serre Lara
# 2      05001_fuxrfi_00003         NaN       3  NaN  Montée du Serre Lara
# 3      05001_fuxrfi_00004         NaN       4  NaN  Montée du Serre Lara
# 4      05001_fuxrfi_00005         NaN       5  NaN  Montée du Serre Lara
# ...                   ...         ...     ...  ...                   ...
# 78772    05007_0270_00123  05007_0270     123  NaN         Rue du Sappet
# 78773    05007_0270_00127  05007_0270     127  NaN         Rue du Sappet
# 78774    05007_0280_00043  05007_0280      43  NaN       Chemin du Stade
# 78775    05007_0290_00025  05007_0290      25  NaN   Impasse de la Teppe
# 78776    05007_0290_00075  05007_0290      75  NaN   Impasse de la Teppe
#
#        code_postal  code_insee      nom_commune  code_insee_ancienne_commune  \
# ...
